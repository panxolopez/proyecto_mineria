# %% [markdown]
# # Proyecto
# ## TEL-354: Minería de Datos 2022-1
# ### Prof. Mauricio Araya

# %% [markdown]
# ## Shootings USA

# %%
import pandas as pd
df_shooting1=pd.read_csv('Mass_shooting_data.csv')
df_shooting1
#df_shooting1.columns.values : array(['Incident ID', 'Incident Date', 'State', 'City Or County','Address', '# Killed', '# Injured', 'Operations'], dtype=object)
# Out:
#       Incident ID    Incident Date                 State City Or County  \
# 0         1978561   April 15, 2021  District of Columbia     Washington
# 1         1978635   April 15, 2021               Indiana   Indianapolis
# 2         1978652   April 15, 2021              Illinois        Chicago
# 3         1978616   April 15, 2021               Florida      Pensacola
# 4         1976538   April 13, 2021              Maryland      Baltimore
# ...           ...              ...                   ...            ...
# 1995       634238  August 20, 2016           Connecticut         Hamden
# 1996       634731  August 20, 2016            Washington         Tacoma
# 1997       634819  August 20, 2016               Alabama     Citronelle
# 1998       632747  August 18, 2016           Connecticut      Waterbury
# 1999       632753  August 17, 2016            California        Oakland
#
#                                  Address  # Killed  # Injured  Operations
# ...

# %% [markdown]
# Tenemos 2000 datos desde el 2016 al 2021 lo que nos da una proporcion de 1.3 tiroteos diarios

# %%
df_shooting=pd.read_csv('MassShootingsDataset.csv', encoding= 'unicode_escape')
df_shooting
# Out:
#       S#                                 Title                Location  \
# 0      1         Las Vegas Strip mass shooting           Las Vegas, NV
# 1      2            San Francisco UPS shooting       San Francisco, CA
# 2      3     Pennsylvania supermarket shooting         Tunkhannock, PA
# 3      4  Florida awning manufacturer shooting        Orlando, Florida
# 4      5      Rural Ohio nursing home shooting      Kirkersville, Ohio
# ..   ...                                   ...                     ...
# 393  394        Clara Barton Elementary School       Chicago, Illinois
# 394  395          New Orleans Police Shootings  New Orleans, Louisiana
# 395  396                   St. Aloysius Church     Spokane, Washington
# 396  397            Rose-Mar College of Beauty           Mesa, Arizona
# 397  398         University of Texas at Austin           Austin, Texas
#
#            Date                                            Summary  \
# ...

# %% [markdown]
# este dataset nos puede serivir como contexto hasta el 2017, de como evoluciono los tiroteos del 66 al 2017

# %%
df_shooting2=pd.read_csv('Mass_Shootings_Dataset_Ver2.csv', encoding= 'unicode_escape')
df_shooting2
# Out:
#       S#                                 Title                Location  \
# 0      1         Las Vegas Strip mass shooting           Las Vegas, NV
# 1      2            San Francisco UPS shooting       San Francisco, CA
# 2      3     Pennsylvania supermarket shooting         Tunkhannock, PA
# 3      4  Florida awning manufacturer shooting        Orlando, Florida
# 4      5      Rural Ohio nursing home shooting      Kirkersville, Ohio
# ..   ...                                   ...                     ...
# 315  316        Clara Barton Elementary School       Chicago, Illinois
# 316  317          New Orleans Police Shootings  New Orleans, Louisiana
# 317  318                   St. Aloysius Church     Spokane, Washington
# 318  319            Rose-Mar College of Beauty           Mesa, Arizona
# 319  320         University of Texas at Austin           Austin, Texas
#
#            Date                                            Summary  \
# ...

# %% [markdown]
# al parecer es el data actualizado del dataset anterior

# %%
df_shooting3=pd.read_csv('Mass_Shootings_Dataset_Ver3.csv', encoding= 'unicode_escape')
df_shooting3
# Out:
#       S#                                 Title                Location  \
# 0      1         Las Vegas Strip mass shooting           Las Vegas, NV
# 1      2            San Francisco UPS shooting       San Francisco, CA
# 2      3     Pennsylvania supermarket shooting         Tunkhannock, PA
# 3      4  Florida awning manufacturer shooting        Orlando, Florida
# 4      5      Rural Ohio nursing home shooting      Kirkersville, Ohio
# ..   ...                                   ...                     ...
# 315  316        Clara Barton Elementary School       Chicago, Illinois
# 316  317          New Orleans Police Shootings  New Orleans, Louisiana
# 317  318                   St. Aloysius Church     Spokane, Washington
# 318  319            Rose-Mar College of Beauty           Mesa, Arizona
# 319  320         University of Texas at Austin           Austin, Texas
#
#            Date                   Incident Area Open/Close Location  \
# ...

# %% [markdown]
# misma que ver 3 pero con mas columnas de datos, habria que limpiar el dataset para ver si son empleados, a primera vista no nos dara info importante ademas no todos son trabajadores, habria que generar disstintas columnas para analizarlas por tipos

# %%
df_shooting4=pd.read_csv('Mass_Shootings_Dataset_Ver4.csv', encoding= 'unicode_escape')
df_shooting4
# Out:
#       S#                                 Title                Location  \
# 0      1         Las Vegas Strip mass shooting           Las Vegas, NV
# 1      2            San Francisco UPS shooting       San Francisco, CA
# 2      3     Pennsylvania supermarket shooting         Tunkhannock, PA
# 3      4  Florida awning manufacturer shooting        Orlando, Florida
# 4      5      Rural Ohio nursing home shooting      Kirkersville, Ohio
# ..   ...                                   ...                     ...
# 315  316        Clara Barton Elementary School       Chicago, Illinois
# 316  317          New Orleans Police Shootings  New Orleans, Louisiana
# 317  318                   St. Aloysius Church     Spokane, Washington
# 318  319            Rose-Mar College of Beauty           Mesa, Arizona
# 319  320         University of Texas at Austin           Austin, Texas
#
#            Date                   Incident Area Open/Close Location  \
# ...

# %%
df_shooting5=pd.read_csv('Mass_Shootings_Dataset_Ver5.csv', encoding= 'unicode_escape')
df_shooting5
# Out:
#       S#                                Title                Location  \
# 0      1           Texas church mass shooting  Sutherland Springs, TX
# 1      2  Walmart shooting in suburban Denver            Thornton, CO
# 2      3      Edgewood businees park shooting            Edgewood, MD
# 3      4        Las Vegas Strip mass shooting           Las Vegas, NV
# 4      5           San Francisco UPS shooting       San Francisco, CA
# ..   ...                                  ...                     ...
# 318  319       Clara Barton Elementary School       Chicago, Illinois
# 319  320         New Orleans Police Shootings  New Orleans, Louisiana
# 320  321                  St. Aloysius Church     Spokane, Washington
# 321  322           Rose-Mar College of Beauty           Mesa, Arizona
# 322  323        University of Texas at Austin           Austin, Texas
#
#            Date                                Incident Area  \
# 0     11/5/2017                                       Church
# ...

# %% [markdown]
# esta es la version final de los datases, le agregan mas datos y acutalizan los datos

# %% [markdown]
# Tuvimos que buscar una nueva data por registrar xq eliminaron las csv

# %% [markdown]
# ##### nuestro objetivo es descubrir si las causantes de los tirotes de usa, es la salud mental, obteniendo esta info a traves de los dataset de kaggle con datos realcionados con la salud mental con datos como si tenia problemas, la causa del tiroteo

# %% [markdown]
# Actualizacion: usaremos el ver5 para el contexto y con el de la actualidad 2000 filas

# %% [markdown]
# ## buscar el dataset de la salud mental en usa y empezar el analisis

# %%
df_shooting5.columns.values
# Out:
# array(['S#', 'Title', 'Location', 'Date', 'Incident Area',
#        'Open/Close Location', 'Target', 'Cause', 'Summary', 'Fatalities',
#        'Injured', 'Total victims', 'Policeman Killed', 'Age',
#        'Employeed (Y/N)', 'Employed at', 'Mental Health Issues', 'Race',
#        'Gender', 'Latitude', 'Longitude'], dtype=object)

# %%
df_shooting5.groupby(['Mental Health Issues']).mean()
# Out:
#                               S#  Fatalities    Injured  Total victims  \
# Mental Health Issues
# No                    195.956989    3.903226   3.408602       6.967742
# Unclear                67.076923   12.769231  50.000000      62.692308
# Unknown                94.027273    2.536364   3.281818       5.472727
# Yes                   214.905660    5.811321   6.283019      11.698113
# unknown               107.000000    9.000000   1.000000      10.000000
#
#                       Policeman Killed  Employeed (Y/N)   Latitude  Longitude
# Mental Health Issues
# No                            0.064516         0.592593  37.542319 -94.265972
# Unclear                       1.000000         1.000000  35.873396 -94.776162
# Unknown                       0.045872         0.833333  36.522983 -92.294018
# Yes                           0.192308         0.535714  37.802552 -97.086961
# unknown                       0.000000              NaN  32.788387 -79.933143

# %%
#los que tienen problemas de salud mental
df_shooting5_mentalYes=df_shooting5[df_shooting5['Mental Health Issues']=='Yes']
df_shooting5_mentalYes
df_shooting5_mentalYes.groupby(['Target']).mean()
# Out:
#                                    S#  Fatalities    Injured  Total victims  \
# Target
# Children                   312.000000    2.500000  10.500000      12.500000
# Congresswoman              197.000000    6.000000  13.000000      19.000000
# Coworker's Family          174.000000    4.000000   2.000000       7.000000
# Coworkers                  268.166667    6.333333   1.500000       7.333333
# Ex-Coworkers               269.142857    5.857143   3.571429       9.000000
# Ex-GirlFriend              228.000000    2.000000   2.000000       4.000000
# Ex-Wife                    200.666667    8.000000   2.000000      10.000000
# Ex-Wife & Family           178.666667    5.333333   2.000000       6.666667
# Family                     108.375000    4.000000   0.500000       4.000000
# Family+students            177.000000   28.000000   2.000000      29.000000
# Marines                    104.000000    5.000000   3.000000       7.000000
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#Coworkers
df_shooting5_CoworksA=df_shooting5[df_shooting5['Target']=='coworkers']
df_shooting5_CoworksB=df_shooting5[df_shooting5['Target']=="Coworker's Family"]
df_shooting5_CoworksC=df_shooting5[df_shooting5['Target']=='Coworkers']
df_shooting5_CoworksD=df_shooting5[df_shooting5['Target']=='Ex-Coworkers']

coworkers = pd.concat([df_shooting5_CoworksA, df_shooting5_CoworksB,df_shooting5_CoworksC,df_shooting5_CoworksD])
coworkers.columns.values
#df_shooting5_Coworks
#df_shooting5_Coworks.groupby(['Target']).mean()
table_all = df_shooting5.dropna(axis=0)
sns.pairplot(table_all, hue="Mental Health Issues")

# %%
import seaborn as sns
import matplotlib.pyplot as plt
def plot_corr_matrix(data,features=None,annot=True,s=(12,8)):
    fig= plt.figure(figsize=s)
    ax= fig.add_subplot(111)
    if features is None:
        corr = data.corr()
    else:
        corr = data[features].corr()
    ax= sns.heatmap(corr,annot=annot,
        xticklabels=corr.columns,
    yticklabels=corr.columns, cmap="seismic",vmin=-1,vmax=1)
    plt.title("Correlation Matrix", fontsize = 15)
    plt.show()

# %%
import pandas

binarios_data_1=pandas.get_dummies(df_shooting5)
correlacion=binarios_data_1.corr(method='pearson')
plot_corr_matrix(correlacion)
# Out:
# C:\Users\pancholopez\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 128 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pancholopez\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 153 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pancholopez\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 146 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pancholopez\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 156 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pancholopez\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 151 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
import matplotlib.pyplot as plt

from datetime import datetime

coworkers['Date'] = pd.to_datetime(coworkers['Date'], format="%Y-%m-%d")

#plt.plot(coworkers['Date'],coworkers['Fatalities'],label="Muertes")
#plt.plot(coworkers['Date'],coworkers['Injured'],label="Heridos")
#plt.plot(coworkers['Date'],coworkers['Total victims'],label="Victimas Totales")
#plt.legend()
#plt.figure(figsize=(10,10))
#plt.show()

# %%
import pandas as pd
mental=pd.read_csv('mental-and-substance-use-as-share-of-disease.csv')
mental
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  1990
# 1     Afghanistan  AFG  1991
# 2     Afghanistan  AFG  1992
# 3     Afghanistan  AFG  1993
# 4     Afghanistan  AFG  1994
# ...           ...  ...   ...
# 6835     Zimbabwe  ZWE  2015
# 6836     Zimbabwe  ZWE  2016
# 6837     Zimbabwe  ZWE  2017
# 6838     Zimbabwe  ZWE  2018
# 6839     Zimbabwe  ZWE  2019
#
#       DALYs (Disability-Adjusted Life Years) - Mental disorders - Sex: Both - Age: All Ages (Percent)
# 0                                              1.696670
# 1                                              1.734281
# 2                                              1.791189
# 3                                              1.776779
# 4                                              1.712986
# ...                                                 ...
# 6835                                           2.193166
# 6836                                           2.279813
# ...

# %%
import pandas as pd
mental_2=pd.read_csv('prevalence-by-mental-and-substance-use-disorder.csv')
mental_2
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  1990
# 1     Afghanistan  AFG  1991
# 2     Afghanistan  AFG  1992
# 3     Afghanistan  AFG  1993
# 4     Afghanistan  AFG  1994
# ...           ...  ...   ...
# 6835     Zimbabwe  ZWE  2015
# 6836     Zimbabwe  ZWE  2016
# 6837     Zimbabwe  ZWE  2017
# 6838     Zimbabwe  ZWE  2018
# 6839     Zimbabwe  ZWE  2019
#
#       Prevalence - Schizophrenia - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                              0.228979
# 1                                              0.228120
# 2                                              0.227328
# 3                                              0.226468
# 4                                              0.225567
# ...                                                 ...
# 6835                                           0.209359
# 6836                                           0.209979
# 6837                                           0.210631
# ...

# %%
usa=(mental_2['Entity']=='United States')
#mental_2.groupby('Entity')
import seaborn as sns
mental_2 = mental_2.sort_values('Entity')
sns.pairplot(mental_2,hue='Entity')

# %%
import pandas as pd
mental_3=pd.read_csv('prevalence-of-depression-males-vs-females.csv')
mental_3
# Out:
#               Entity      Code  Year  \
# 0           Abkhazia  OWID_ABK  2015
# 1        Afghanistan       AFG  1990
# 2        Afghanistan       AFG  1991
# 3        Afghanistan       AFG  1992
# 4        Afghanistan       AFG  1993
# ...              ...       ...   ...
# 56390       Zimbabwe       ZWE  1988
# 56391       Zimbabwe       ZWE  1989
# 56392       Zimbabwe       ZWE  2020
# 56393       Zimbabwe       ZWE  2021
# 56394  Åland Islands       ALA  2015
#
#        Prevalence - Depressive disorders - Sex: Male - Age: Age-standardized (Percent)  \
# 0                                                    NaN
# 1                                               4.291054
# 2                                               4.293268
# 3                                               4.298265
# 4                                               4.303087
# ...                                                  ...
# 56390                                                NaN
# ...

# %%
mental_3.groupby('Entity')

# %%
import pandas as pd
mental_4=pd.read_csv('share-with-depression.csv')
mental_4
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  1990
# 1     Afghanistan  AFG  1991
# 2     Afghanistan  AFG  1992
# 3     Afghanistan  AFG  1993
# 4     Afghanistan  AFG  1994
# ...           ...  ...   ...
# 6775     Zimbabwe  ZWE  2015
# 6776     Zimbabwe  ZWE  2016
# 6777     Zimbabwe  ZWE  2017
# 6778     Zimbabwe  ZWE  2018
# 6779     Zimbabwe  ZWE  2019
#
#       Prevalence - Depressive disorders - Sex: Both - Age: Age-standardized (Percent)
# 0                                              5.125291
# 1                                              5.116306
# 2                                              5.106558
# 3                                              5.100328
# 4                                              5.099424
# ...                                                 ...
# 6775                                           3.548613
# 6776                                           3.557508
# 6777                                           3.564138
# ...

# %%
import pandas as pd
mental_5=pd.read_csv('share-with-mental-and-substance-disorders.csv')
mental_5
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  1990
# 1     Afghanistan  AFG  1991
# 2     Afghanistan  AFG  1992
# 3     Afghanistan  AFG  1993
# 4     Afghanistan  AFG  1994
# ...           ...  ...   ...
# 6775     Zimbabwe  ZWE  2015
# 6776     Zimbabwe  ZWE  2016
# 6777     Zimbabwe  ZWE  2017
# 6778     Zimbabwe  ZWE  2018
# 6779     Zimbabwe  ZWE  2019
#
#       Prevalence - Mental disorders - Sex: Both - Age: Age-standardized (Percent)
# 0                                             16.659229
# 1                                             16.765052
# 2                                             16.874469
# 3                                             16.990720
# 4                                             17.112730
# ...                                                 ...
# 6775                                          11.156429
# 6776                                          11.164133
# 6777                                          11.170427
# ...

# %%
import pandas as pd
mental_6=pd.read_csv('share-with-mental-or-substance-disorders-by-sex.csv')
mental_6
# Out:
#               Entity      Code  Year  \
# 0           Abkhazia  OWID_ABK  2015
# 1        Afghanistan       AFG  1990
# 2        Afghanistan       AFG  1991
# 3        Afghanistan       AFG  1992
# 4        Afghanistan       AFG  1993
# ...              ...       ...   ...
# 56624       Zimbabwe       ZWE  2018
# 56625       Zimbabwe       ZWE  2019
# 56626       Zimbabwe       ZWE  2020
# 56627       Zimbabwe       ZWE  2021
# 56628  Åland Islands       ALA  2015
#
#        Prevalence - Mental and substance use disorders - Sex: Male - Age: Age-standardized (Percent)  \
# 0                                                    NaN
# 1                                              17.448695
# 2                                              17.771263
# 3                                              18.051575
# 4                                              18.275848
# ...                                                  ...
# 56624                                                NaN
# ...
